# %% [markdown]
# # HS4002 Week 1 Demo
#
# # HELLO HELLO
#
# ## Basics of Python
#
# We're working within the **pandas** + **plotnine** framework.
#
# Firstly, We will explore a toy dataset about *Love Is Blind* contestants to answer: **to what extent does age, gender, and race affect the likelihood of marriage in LIB?**

# %%
import pandas as pd
import numpy as np
import plotnine as p9
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Loading the Dataset

# %%
file_location = "lib_toy.csv"
df = pd.read_csv(file_location)

# %% [markdown]
# # What does a dataset usually look like?

# %%
df.head()
# Out:
#                Name  Season           Partner  Age  Married      Race  Gender  \
# 0      Lauren Speed       1  Cameron Hamilton   32        1     Black       1
# 1  Cameron Hamilton       1      Lauren Speed   28        1     White       0
# 2        Amber Pike       1   Matthew Barnett   27        1     White       1
# 3   Matthew Barnett       1        Amber Pike   27        1     White       0
# 4  Giannina Gibelli       1     Damian Powers   25        0  Hispanic       1
#
#                Unnamed: 7
# 0      LIB + Lauren Speed
# 1  LIB + Cameron Hamilton
# 2        LIB + Amber Pike
# 3   LIB + Matthew Barnett
# 4  LIB + Giannina Gibelli

# %% [markdown]
# # Univariate Analysis

# %%
df.describe()
# Out:
#            Season         Age     Married      Gender
# count  120.000000  120.000000  120.000000  120.000000
# mean     5.650000   30.708333    0.266667    0.500000
# std      2.972281    3.090772    0.444071    0.502096
# min      1.000000   24.000000    0.000000    0.000000
# 25%      3.000000   28.000000    0.000000    0.000000
# 50%      6.000000   31.000000    0.000000    0.500000
# 75%      8.000000   33.000000    1.000000    1.000000
# max     10.000000   39.000000    1.000000    1.000000

# %%
df['Race'].value_counts()
# Out:
# Race
# White       67
# Black       33
# Hispanic    12
# Asian        6
# Mixed        2
# Name: count, dtype: int64

# %% [markdown]
# ## How many seasons of LIB are in this dataset?

# %%
df['Season'].value_counts()
# Out:
# Season
# 10    16
# 4     14
# 7     14
# 1     12
# 2     12
# 9     12
# 3     10
# 5     10
# 6     10
# 8     10
# Name: count, dtype: int64

# %% [markdown]
# ## How many contestants got married?

# %%
df['Married'].value_counts()
# Out:
# Married
# 0    88
# 1    32
# Name: count, dtype: int64

# %% [markdown]
# ## Univariate Plots
#
# Let's make a histogram of the age distribution using `plotnine` — the grammar is identical to ggplot2. Note that column names in `aes()` are quoted strings in Python.

# %%
(
    p9.ggplot(df) +
    p9.geom_histogram(p9.aes(x='Age'), binwidth=0.5)
)

# %%
fig_fn = "ntu4eva.png"

p = (
    p9.ggplot(df) +
    p9.geom_histogram(p9.aes(x="Age"), binwidth=0.5, fill="red") +
    p9.theme_light() +
    p9.xlim(18, 40) +
    p9.labs(y="Count", x="Age", title="Age Distribution of Love is Blind Contestants")
)
p.save(fig_fn, width=30, height=17, units="cm")
p

# %%
fig_fn = "ntu4eva.png"

p = (
    p9.ggplot(df) +
    p9.geom_density(p9.aes(x="Age"), fill="steelblue") +
    p9.theme_light() +
    p9.xlim(18, 40) +
    p9.labs(y="Density", x="Age", title="Age of Love is Blind Contestants")
)
p.save(fig_fn, width=30, height=17, units="cm")
p

# %% [markdown]
# # Does Age Matter?
#
# How does age relate to the likelihood of a contestant getting married?

# %%
df.groupby('Married')['Age'].mean()
# Out:
# Married
# 0    30.636364
# 1    30.906250
# Name: Age, dtype: float64

# %%
fig_fn = "age_by_maritalstatus.png"

p = (
    p9.ggplot(df) +
    p9.geom_density(p9.aes(x="Age", fill="factor(Married)"), position="identity", alpha=0.5) +
    p9.theme_light() +
    p9.xlim(18, 40) +
    p9.labs(y="Density", x="Age",
         title="Age Distribution of Love is Blind Contestants",
         fill="Married")
)
p.save(fig_fn, width=30, height=17, units="cm")
p

# %% [markdown]
# # Let's Throw Race Into the Mix

# %%
df.groupby(['Married', 'Race'])['Age'].mean()
# Out:
# Married  Race
# 0        Asian       30.500000
#          Black       30.700000
#          Hispanic    29.700000
#          White       30.807692
# 1        Black       32.076923
#          Hispanic    30.000000
#          Mixed       31.500000
#          White       29.933333
# Name: Age, dtype: float64

# %%
fig_fn = "age_marital_race.png"

p = (
    p9.ggplot(df) +
    p9.geom_density(p9.aes(x="Age", fill="factor(Married)"), position="identity", alpha=0.5) +
    p9.facet_wrap("Race") +
    p9.theme_light() +
    p9.xlim(18, 40) +
    p9.labs(y="Density", x="Age",
         title="Age Distribution of Love is Blind Contestants",
         fill="Married")
)
p.save(fig_fn, width=30, height=17, units="cm")
p

# %% [markdown]
# # Trying Adding Gender!

# %%
df = df.assign(Gender=np.where(df['Gender'] == 1, 'Woman', 'Man'))

df.groupby(['Married', 'Gender'])['Age'].mean()
# Out:
# Married  Gender
# 0        Man       30.204545
#          Woman     31.068182
# 1        Man       31.250000
#          Woman     30.562500
# Name: Age, dtype: float64

# %%
fig_fn = "age_marital_gender.png"

p = (
    p9.ggplot(df) +
    p9.geom_density(p9.aes(x="Age", fill="factor(Married)"), position="identity", alpha=0.5) +
    p9.facet_wrap("Gender") +
    p9.theme_light() +
    p9.xlim(18, 40) +
    p9.labs(y="Density", x="Age",
         title="Age Distribution of Love is Blind Contestants",
         fill="Married")
)
p.save(fig_fn, width=30, height=17, units="cm")
p
